# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard.notebook

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import time
import os
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# set up tensorboard log directory
logdir="tf_logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
os.makedirs(logdir, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# need the following to successfully run. 
# Otherwise there will be cuDNN error in training 
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)
sess.as_default()

# %%
# define dataloader and preprocessing
def load_and_preprocess_image(path):
    image = tf.io.read_file(path)
    return preprocess_image(image)

def preprocess_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize_with_pad(image, 256, 256)
    image = tf.image.random_crop(image, (224, 224, 3))
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, 0.2)
    image = image/255  # normalize to [0,1] range
    return image
path = "/home/nan/sneaker_ai/screened_data/air_jordan_1/air_jordan_1_362.png"
plt.imshow(load_and_preprocess_image(path))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0417 12:22:03.210203 139953312876288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# test random data loaders
import random
train_df = pd.read_csv("train_df.csv")
indx = random.randint(0, len(train_df))
path = train_df.iloc[indx, 1]
print(path)
plt.imshow(load_and_preprocess_image(path))
# Out:
# W0417 12:22:03.464568 139953312876288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/nan/sneaker_ai/screened_data/air_jordan_6/air_jordan_6_60.jpg

# %%
# set up datasets
from sklearn.utils import shuffle
train_df = shuffle(train_df)
train_image_paths = train_df.loc[:, "Image_File"].tolist()
train_image_labels = train_df.loc[:, "Label"].tolist()

test_df = pd.read_csv("test_df.csv")
# test_df = shuffle(test_df)
test_image_paths = test_df.loc[:, "Image_File"].tolist()
test_image_labels = test_df.loc[:, "Label"].tolist()
# covertion between class names and model outputs
label_names = ["AJ "+str(i) for i in range(1,24)]
label_to_index = dict((name, index) 
                      for index, name in enumerate(label_names))

train_ds = tf.data.Dataset.from_tensor_slices((train_image_paths, train_image_labels))
test_ds = tf.data.Dataset.from_tensor_slices((test_image_paths, test_image_labels))

# The tuples are unpacked into the positional arguments of the mapped function 
def load_and_preprocess_from_path_label(path, label):
    return load_and_preprocess_image(path), label

train_ds = train_ds.map(load_and_preprocess_from_path_label)
test_ds = test_ds.map(load_and_preprocess_from_path_label)

# %%
# specify batch size and buffering for datasets
BATCH_SIZE = 64

# # Setting a shuffle buffer size as large as the dataset ensures that the data is
# # completely shuffled.
# train_ds = train_ds.apply(
#   tf.data.experimental.shuffle_and_repeat(buffer_size=len(train_df)))
# do the following to save some ram, otherwise training will stop
train_ds = train_ds.apply(
  tf.data.experimental.shuffle_and_repeat(buffer_size=256))
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# do the following to save some ram, otherwise training will stop
test_ds = test_ds.apply(
  tf.data.experimental.shuffle_and_repeat(buffer_size=256))
# test_ds = test_ds.apply(
#   tf.data.experimental.shuffle_and_repeat(buffer_size=len(test_df)))
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
# import mobilenet v2 model
mobile_net = tf.keras.applications.MobileNetV2(input_shape=(224,224, 3), include_top=False)
# mobile_net.trainable=False
mobile_net.trainable=True

# %%
# MobileNetV2: https://github.com/keras-team/keras-applications/blob/master/keras_applications/mobilenet_v2.py
# imagenet.utils: https://github.com/keras-team/keras-applications/blob/master/keras_applications/imagenet_utils.py
# mobile net expects prepocessed input ranging from -1 to 1
def change_range(image,label):
    return 2*image-1, label

train_ds = train_ds.map(change_range)
test_ds = test_ds.map(change_range)

# %%
# add fc layers after mobilenet for transfer learning
model = tf.keras.Sequential([
    mobile_net,
    # take an average of each channel so that the model woks with different input sizes
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation = tf.nn.relu),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation = tf.nn.relu),
#     tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(label_names), activation=tf.nn.softmax)])

# %%
# configure model optimizer, loss
# model.compile(optimizer=tf.optimizers.Adam(learning_rate=5e-6), 
#               loss=tf.keras.losses.sparse_categorical_crossentropy,
#               metrics=["accuracy"])

# learning_rate=5e-6 was tuned for batch size 16
# larger batch allows for greater learning rate
model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-5), 
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               655872
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 23)                2967
# =================================================================
# Total params: 2,982,487
# Trainable params: 2,948,375
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
# %tensorboard --logdir {logdir}
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:6006"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# model training
num_epochs = 60
training_history = model.fit(train_ds, epochs=num_epochs, 
                             validation_data=test_ds,
                             callbacks=[tensorboard_callback],
#                              verbose=2,
                            )
# Out:
# Epoch 1/60
# 89/89 [==============================] - 124s 1s/step - loss: 3.3337 - accuracy: 0.0460 - val_loss: 3.1351 - val_accuracy: 0.0659
# Epoch 2/60
# 89/89 [==============================] - 76s 858ms/step - loss: 3.1618 - accuracy: 0.0699 - val_loss: 3.0345 - val_accuracy: 0.0938
# Epoch 3/60
# 89/89 [==============================] - 76s 859ms/step - loss: 3.0581 - accuracy: 0.0897 - val_loss: 2.9511 - val_accuracy: 0.1345
# Epoch 4/60
# 89/89 [==============================] - 76s 859ms/step - loss: 2.9338 - accuracy: 0.1354 - val_loss: 2.8589 - val_accuracy: 0.1800
# Epoch 5/60
# 89/89 [==============================] - 76s 857ms/step - loss: 2.8253 - accuracy: 0.1824 - val_loss: 2.7302 - val_accuracy: 0.2412
# Epoch 6/60
# 89/89 [==============================] - 76s 854ms/step - loss: 2.7090 - accuracy: 0.2244 - val_loss: 2.6001 - val_accuracy: 0.3016
# Epoch 7/60
# 89/89 [==============================] - 76s 854ms/step - loss: 2.5363 - accuracy: 0.2988 - val_loss: 2.4377 - val_accuracy: 0.3587
# Epoch 8/60
# 89/89 [==============================] - 76s 855ms/step - loss: 2.3521 - accuracy: 0.3569 - val_loss: 2.2695 - val_accuracy: 0.4124
# Epoch 9/60
# 89/89 [==============================] - 76s 855ms/step - loss: 2.1529 - accuracy: 0.4126 - val_loss: 2.0774 - val_accuracy: 0.4490
# Epoch 10/60
# 89/89 [==============================] - 76s 853ms/step - loss: 1.9701 - accuracy: 0.4705 - val_loss: 1.8808 - val_accuracy: 0.5095
# Epoch 11/60
# 89/89 [==============================] - 76s 855ms/step - loss: 1.7458 - accuracy: 0.5372 - val_loss: 1.6987 - val_accuracy: 0.5543
# Epoch 12/60
# 89/89 [==============================] - 76s 855ms/step - loss: 1.5785 - accuracy: 0.5841 - val_loss: 1.5358 - val_accuracy: 0.5890
# Epoch 13/60
# 89/89 [==============================] - 76s 855ms/step - loss: 1.4171 - accuracy: 0.6224 - val_loss: 1.4066 - val_accuracy: 0.6182
# Epoch 14/60
# 89/89 [==============================] - 76s 857ms/step - loss: 1.2735 - accuracy: 0.6656 - val_loss: 1.2918 - val_accuracy: 0.6474
# Epoch 15/60
# 89/89 [==============================] - 75s 845ms/step - loss: 1.1571 - accuracy: 0.6912 - val_loss: 1.1878 - val_accuracy: 0.6814
# Epoch 16/60
# 89/89 [==============================] - 76s 857ms/step - loss: 1.0602 - accuracy: 0.7149 - val_loss: 1.1116 - val_accuracy: 0.7011
# Epoch 17/60
# 89/89 [==============================] - 76s 854ms/step - loss: 0.9589 - accuracy: 0.7470 - val_loss: 1.0562 - val_accuracy: 0.7038
# Epoch 18/60
# 89/89 [==============================] - 76s 855ms/step - loss: 0.8829 - accuracy: 0.7656 - val_loss: 0.9995 - val_accuracy: 0.7303
# Epoch 19/60
# 89/89 [==============================] - 76s 857ms/step - loss: 0.8039 - accuracy: 0.7834 - val_loss: 0.9417 - val_accuracy: 0.7425
# Epoch 20/60
# 89/89 [==============================] - 77s 861ms/step - loss: 0.7501 - accuracy: 0.8014 - val_loss: 0.9054 - val_accuracy: 0.7568
# Epoch 21/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.6935 - accuracy: 0.8092 - val_loss: 0.8678 - val_accuracy: 0.7643
# Epoch 22/60
# 89/89 [==============================] - 76s 852ms/step - loss: 0.6421 - accuracy: 0.8297 - val_loss: 0.8267 - val_accuracy: 0.7833
# Epoch 23/60
# 89/89 [==============================] - 76s 854ms/step - loss: 0.6067 - accuracy: 0.8376 - val_loss: 0.8265 - val_accuracy: 0.7792
# Epoch 24/60
# 89/89 [==============================] - 76s 859ms/step - loss: 0.5553 - accuracy: 0.8522 - val_loss: 0.7834 - val_accuracy: 0.7880
# Epoch 25/60
# 89/89 [==============================] - 76s 858ms/step - loss: 0.5283 - accuracy: 0.8596 - val_loss: 0.7702 - val_accuracy: 0.7935
# Epoch 26/60
# 89/89 [==============================] - 76s 852ms/step - loss: 0.4894 - accuracy: 0.8692 - val_loss: 0.7417 - val_accuracy: 0.8084
# Epoch 27/60
# 89/89 [==============================] - 76s 854ms/step - loss: 0.4629 - accuracy: 0.8792 - val_loss: 0.7262 - val_accuracy: 0.8037
# Epoch 28/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.4227 - accuracy: 0.8899 - val_loss: 0.7166 - val_accuracy: 0.8111
# Epoch 29/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.3972 - accuracy: 0.8955 - val_loss: 0.7004 - val_accuracy: 0.8132
# Epoch 30/60
# 89/89 [==============================] - 76s 854ms/step - loss: 0.3763 - accuracy: 0.8989 - val_loss: 0.6930 - val_accuracy: 0.8247
# Epoch 31/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.3499 - accuracy: 0.9075 - val_loss: 0.6869 - val_accuracy: 0.8227
# Epoch 32/60
# 89/89 [==============================] - 76s 859ms/step - loss: 0.3234 - accuracy: 0.9171 - val_loss: 0.6629 - val_accuracy: 0.8234
# Epoch 33/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.3111 - accuracy: 0.9205 - val_loss: 0.6457 - val_accuracy: 0.8322
# Epoch 34/60
# 89/89 [==============================] - 76s 855ms/step - loss: 0.2912 - accuracy: 0.9259 - val_loss: 0.6567 - val_accuracy: 0.8363
# Epoch 35/60
# 89/89 [==============================] - 76s 855ms/step - loss: 0.2559 - accuracy: 0.9371 - val_loss: 0.6308 - val_accuracy: 0.8458
# Epoch 36/60
# 89/89 [==============================] - 75s 840ms/step - loss: 0.2506 - accuracy: 0.9335 - val_loss: 0.6277 - val_accuracy: 0.8376
# Epoch 37/60
# 89/89 [==============================] - 76s 853ms/step - loss: 0.2265 - accuracy: 0.9431 - val_loss: 0.6178 - val_accuracy: 0.8458
# Epoch 38/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.2195 - accuracy: 0.9452 - val_loss: 0.6020 - val_accuracy: 0.8539
# Epoch 39/60
# 89/89 [==============================] - 76s 857ms/step - loss: 0.2028 - accuracy: 0.9473 - val_loss: 0.6195 - val_accuracy: 0.8546
# Epoch 40/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.1857 - accuracy: 0.9566 - val_loss: 0.6055 - val_accuracy: 0.8444
# Epoch 41/60
# 89/89 [==============================] - 76s 849ms/step - loss: 0.1819 - accuracy: 0.9531 - val_loss: 0.6025 - val_accuracy: 0.8499
# Epoch 42/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.1621 - accuracy: 0.9570 - val_loss: 0.5949 - val_accuracy: 0.8546
# Epoch 43/60
# 89/89 [==============================] - 77s 860ms/step - loss: 0.1540 - accuracy: 0.9628 - val_loss: 0.5906 - val_accuracy: 0.8580
# Epoch 44/60
# 89/89 [==============================] - 76s 855ms/step - loss: 0.1386 - accuracy: 0.9668 - val_loss: 0.5898 - val_accuracy: 0.8573
# Epoch 45/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.1296 - accuracy: 0.9707 - val_loss: 0.6157 - val_accuracy: 0.8533
# Epoch 46/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.1272 - accuracy: 0.9682 - val_loss: 0.5926 - val_accuracy: 0.8573
# Epoch 47/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.1175 - accuracy: 0.9733 - val_loss: 0.5858 - val_accuracy: 0.8594
# Epoch 48/60
# 89/89 [==============================] - 76s 857ms/step - loss: 0.1035 - accuracy: 0.9786 - val_loss: 0.5729 - val_accuracy: 0.8682
# Epoch 49/60
# 89/89 [==============================] - 76s 853ms/step - loss: 0.1011 - accuracy: 0.9759 - val_loss: 0.6012 - val_accuracy: 0.8567
# Epoch 50/60
# 89/89 [==============================] - 76s 857ms/step - loss: 0.0953 - accuracy: 0.9775 - val_loss: 0.5997 - val_accuracy: 0.8553
# Epoch 51/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.0841 - accuracy: 0.9838 - val_loss: 0.5914 - val_accuracy: 0.8641
# Epoch 52/60
# 89/89 [==============================] - 75s 845ms/step - loss: 0.0836 - accuracy: 0.9819 - val_loss: 0.6166 - val_accuracy: 0.8614
# Epoch 53/60
# 89/89 [==============================] - 76s 855ms/step - loss: 0.0727 - accuracy: 0.9858 - val_loss: 0.5961 - val_accuracy: 0.8635
# Epoch 54/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.0706 - accuracy: 0.9879 - val_loss: 0.6111 - val_accuracy: 0.8648
# Epoch 55/60
# 89/89 [==============================] - 76s 857ms/step - loss: 0.0641 - accuracy: 0.9874 - val_loss: 0.6008 - val_accuracy: 0.8668
# Epoch 56/60
# 89/89 [==============================] - 76s 854ms/step - loss: 0.0590 - accuracy: 0.9893 - val_loss: 0.5857 - val_accuracy: 0.8682
# Epoch 57/60
# 89/89 [==============================] - 76s 857ms/step - loss: 0.0599 - accuracy: 0.9879 - val_loss: 0.6034 - val_accuracy: 0.8635
# Epoch 58/60
# 89/89 [==============================] - 76s 856ms/step - loss: 0.0572 - accuracy: 0.9896 - val_loss: 0.5932 - val_accuracy: 0.8709
# Epoch 59/60
# 89/89 [==============================] - 76s 854ms/step - loss: 0.0507 - accuracy: 0.9896 - val_loss: 0.6094 - val_accuracy: 0.8628
# Epoch 60/60
# 89/89 [==============================] - 76s 855ms/step - loss: 0.0444 - accuracy: 0.9916 - val_loss: 0.6058 - val_accuracy: 0.8662

# %%
 sess.close()
