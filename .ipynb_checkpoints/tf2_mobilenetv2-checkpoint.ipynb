# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard.notebook

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import time
import os
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# set up tensorboard log directory
logdir="tf_logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
os.makedirs(logdir, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# need the following to successfully run. 
# Otherwise there will be cuDNN error in training 
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)
sess.as_default()

# %%
import skimage
import random

# define dataloader and preprocessing
def load_and_preprocess_image(path):
    image = tf.io.read_file(path)
    return preprocess_image(image)

# the following does not work with eager execution
def preprocess_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = image/255  # normalize to [0,1] range
    image = tf.image.resize_with_pad(image, 256, 256)
    image = tf.image.random_crop(image, (224, 224, 3))
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.image.random_saturation(image, 0.8, 1.2)
    # tensorflow2.0 does not have tf.conrib.image.rotate()
#     image = tf.convert_to_tensor(skimage.transform.rotate(image.numpy(), rot_angle))
    return image

# # define dataloader and preprocessing
# def load_and_preprocess_image(path):
#     image = tf.io.read_file(path)
#     return preprocess_image(image)

# # the following does not work with eager execution
# def preprocess_image(image):
#     image = tf.image.decode_jpeg(image, channels=3)
#     image = image/255  # normalize to [0,1] range
#     # randomly rotate image for data augmentation
#     rotate_range=30
#     rot_angle = random.randint(-rotate_range, rotate_range)
#     image = tf.convert_to_tensor(skimage.transform.rotate(image.numpy(), rot_angle))
#     image = tf.image.resize_with_pad(image, 256, 256)
#     image = tf.image.random_crop(image, (224, 224, 3))
#     image = tf.image.random_flip_left_right(image)
#     image = tf.image.random_brightness(image, 0.3)
#     image = tf.image.random_contrast(image, 0.7, 1.3)
#     image = tf.image.random_saturation(image, 0.7, 1.3)
#     # tensorflow2.0 does not have tf.conrib.image.rotate()
# #     image = tf.convert_to_tensor(skimage.transform.rotate(image.numpy(), rot_angle))
#     return image

# def load_and_preprocess_image(path):
#     return preprocess_image(path)
# def preprocess_image(image):
#     image = skimage.io.imread(image)
# #     image = tf.image.decode_jpeg(image, channels=3)
#     image = image/255  # normalize to [0,1] range
#     # randomly rotate image for data augmentation
# #     print(image)
#     rotate_range=30
#     rot_angle = random.randint(-rotate_range, rotate_range)
#     image = skimage.transform.rotate(image, rot_angle)
#     image = tf.convert_to_tensor(image)
#     image = tf.image.resize_with_pad(image, 256, 256)
#     image = tf.image.random_crop(image, (224, 224, 3))
#     image = tf.image.random_flip_left_right(image)
#     image = tf.image.random_brightness(image, 0.3)
#     image = tf.image.random_contrast(image, 0.7, 1.3)
#     image = tf.image.random_saturation(image, 0.7, 1.3)
#     # tensorflow2.0 does not have tf.conrib.image.rotate()
# #     image = tf.convert_to_tensor(skimage.transform.rotate(image.numpy(), rot_angle))
#     return image

path = "/home/nan/sneaker_ai/screened_data/air_jordan_1/air_jordan_1_362.png"
plt.imshow(load_and_preprocess_image(path))
# Out:
# W0418 00:06:18.663084 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# test random data loaders
train_df = pd.read_csv("train_df.csv")
indx = random.randint(0, len(train_df))
path = train_df.iloc[indx, 1]
print(path)
plt.imshow(load_and_preprocess_image(path))
# Out:
# W0417 22:03:30.948915 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/nan/sneaker_ai/screened_data/air_jordan_2/air_jordan_2_226.jpg

# %%
# set up datasets
from sklearn.utils import shuffle
train_df = shuffle(train_df)
train_image_paths = train_df.loc[:, "Image_File"].tolist()
train_image_labels = train_df.loc[:, "Label"].tolist()

test_df = pd.read_csv("test_df.csv")
# test_df = shuffle(test_df)
test_image_paths = test_df.loc[:, "Image_File"].tolist()
test_image_labels = test_df.loc[:, "Label"].tolist()
# covertion between class names and model outputs
label_names = ["AJ "+str(i) for i in range(1,24)]
label_to_index = dict((name, index) 
                      for index, name in enumerate(label_names))

train_ds = tf.data.Dataset.from_tensor_slices((train_image_paths, train_image_labels))
test_ds = tf.data.Dataset.from_tensor_slices((test_image_paths, test_image_labels))

# The tuples are unpacked into the positional arguments of the mapped function 
def load_and_preprocess_from_path_label(path, label):
    return load_and_preprocess_image(path), label

train_ds = train_ds.map(load_and_preprocess_from_path_label)
test_ds = test_ds.map(load_and_preprocess_from_path_label)

# %%
# specify batch size and buffering for datasets
BATCH_SIZE = 64

# # Setting a shuffle buffer size as large as the dataset ensures that the data is
# # completely shuffled.
# train_ds = train_ds.apply(
#   tf.data.experimental.shuffle_and_repeat(buffer_size=len(train_df)))
# do the following to save some ram, otherwise training will stop
train_ds = train_ds.apply(
  tf.data.experimental.shuffle_and_repeat(buffer_size=256))
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# do the following to save some ram, otherwise training will stop
test_ds = test_ds.apply(
  tf.data.experimental.shuffle_and_repeat(buffer_size=256))
# test_ds = test_ds.apply(
#   tf.data.experimental.shuffle_and_repeat(buffer_size=len(test_df)))
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
# import mobilenet v2 model
mobile_net = tf.keras.applications.MobileNetV2(input_shape=(224,224, 3), include_top=False)
# mobile_net.trainable=False
mobile_net.trainable=True

# %%
# MobileNetV2: https://github.com/keras-team/keras-applications/blob/master/keras_applications/mobilenet_v2.py
# imagenet.utils: https://github.com/keras-team/keras-applications/blob/master/keras_applications/imagenet_utils.py
# mobile net expects prepocessed input ranging from -1 to 1
def change_range(image,label=0):
    return 2*image-1, label

train_ds = train_ds.map(change_range)
test_ds = test_ds.map(change_range)

# %%
regularizer = 0.1;
# add fc layers after mobilenet for transfer learning
model = tf.keras.Sequential([
    mobile_net,
    # take an average of each channel so that the model woks with different input sizes
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(512, activation = tf.nn.relu),
    tf.keras.layers.Dense(256, activation = tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(regularizer)),
    tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(128, activation = tf.nn.relu),
    tf.keras.layers.Dense(64, activation = tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(regularizer)),
#     tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(label_names), activation=tf.nn.softmax, kernel_regularizer=tf.keras.regularizers.l2(regularizer))])

# %%
# configure model optimizer, loss
# model.compile(optimizer=tf.optimizers.Adam(learning_rate=5e-6), 
#               loss=tf.keras.losses.sparse_categorical_crossentropy,
#               metrics=["accuracy"])

# learning_rate=5e-6 was tuned for batch size 16
# larger batch allows for greater learning rate
model.compile(optimizer=tf.optimizers.Adam(learning_rate=5e-5), 
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               327936
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 23)                1495
# =================================================================
# Total params: 2,603,863
# Trainable params: 2,569,751
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
# %tensorboard --logdir {logdir}
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:6009"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# model training
num_epochs = 30
training_history = model.fit(train_ds, epochs=num_epochs, 
                             validation_data=test_ds,
                             callbacks=[tensorboard_callback],
                             verbose=2,
                            )
# Out:
# Epoch 1/30
# 89/89 - 149s - loss: 56.6065 - accuracy: 0.0474 - val_loss: 52.8212 - val_accuracy: 0.0482
# Epoch 2/30
# 89/89 - 98s - loss: 49.2349 - accuracy: 0.0662 - val_loss: 45.9131 - val_accuracy: 0.0591
# Epoch 3/30
# 89/89 - 99s - loss: 42.6572 - accuracy: 0.0888 - val_loss: 39.6770 - val_accuracy: 0.0802
# Epoch 4/30
# 89/89 - 99s - loss: 36.8118 - accuracy: 0.1338 - val_loss: 34.1578 - val_accuracy: 0.1325
# Epoch 5/30
# 89/89 - 99s - loss: 31.6860 - accuracy: 0.1868 - val_loss: 29.3592 - val_accuracy: 0.1984
# Epoch 6/30
# 89/89 - 99s - loss: 27.2615 - accuracy: 0.2428 - val_loss: 25.2381 - val_accuracy: 0.2962
# Epoch 7/30
# 89/89 - 98s - loss: 23.4161 - accuracy: 0.3432 - val_loss: 21.7229 - val_accuracy: 0.4341
# Epoch 8/30
# 89/89 - 95s - loss: 20.1151 - accuracy: 0.4610 - val_loss: 18.6984 - val_accuracy: 0.5713
# Epoch 9/30
# 89/89 - 98s - loss: 17.2932 - accuracy: 0.5904 - val_loss: 16.1372 - val_accuracy: 0.6467
# Epoch 10/30
# 89/89 - 97s - loss: 14.9580 - accuracy: 0.6682 - val_loss: 14.0054 - val_accuracy: 0.7086
# Epoch 11/30
# 89/89 - 99s - loss: 12.9852 - accuracy: 0.7440 - val_loss: 12.2214 - val_accuracy: 0.7351
# Epoch 12/30
# 89/89 - 98s - loss: 11.3438 - accuracy: 0.7846 - val_loss: 10.7281 - val_accuracy: 0.7772
# Epoch 13/30
# 89/89 - 100s - loss: 9.9710 - accuracy: 0.8299 - val_loss: 9.4658 - val_accuracy: 0.8023
# Epoch 14/30
# 89/89 - 96s - loss: 8.8077 - accuracy: 0.8513 - val_loss: 8.4223 - val_accuracy: 0.8125
# Epoch 15/30
# 89/89 - 96s - loss: 7.8377 - accuracy: 0.8789 - val_loss: 7.5492 - val_accuracy: 0.8145
# Epoch 16/30
# 89/89 - 94s - loss: 7.0176 - accuracy: 0.8943 - val_loss: 6.8197 - val_accuracy: 0.8329
# Epoch 17/30
# 89/89 - 94s - loss: 6.3094 - accuracy: 0.9096 - val_loss: 6.1978 - val_accuracy: 0.8444
# Epoch 18/30
# 89/89 - 96s - loss: 5.7202 - accuracy: 0.9236 - val_loss: 5.6689 - val_accuracy: 0.8505
# Epoch 19/30
# 89/89 - 94s - loss: 5.2150 - accuracy: 0.9343 - val_loss: 5.2192 - val_accuracy: 0.8505
# Epoch 20/30
# 89/89 - 95s - loss: 4.7841 - accuracy: 0.9414 - val_loss: 4.8298 - val_accuracy: 0.8723
# Epoch 21/30
# 89/89 - 97s - loss: 4.4145 - accuracy: 0.9566 - val_loss: 4.4992 - val_accuracy: 0.8730
# Epoch 22/30
# 89/89 - 97s - loss: 4.0957 - accuracy: 0.9607 - val_loss: 4.2185 - val_accuracy: 0.8696
# Epoch 23/30
# 89/89 - 95s - loss: 3.8181 - accuracy: 0.9673 - val_loss: 3.9597 - val_accuracy: 0.8791
# Epoch 24/30
# 89/89 - 97s - loss: 3.5778 - accuracy: 0.9682 - val_loss: 3.7372 - val_accuracy: 0.8696
# Epoch 25/30
# 89/89 - 97s - loss: 3.3725 - accuracy: 0.9726 - val_loss: 3.5521 - val_accuracy: 0.8736
# Epoch 26/30
# 89/89 - 97s - loss: 3.1883 - accuracy: 0.9765 - val_loss: 3.3815 - val_accuracy: 0.8818
# Epoch 27/30
# 89/89 - 97s - loss: 3.0182 - accuracy: 0.9800 - val_loss: 3.2253 - val_accuracy: 0.8791
# Epoch 28/30
# 89/89 - 95s - loss: 2.8719 - accuracy: 0.9821 - val_loss: 3.0760 - val_accuracy: 0.8791
# Epoch 29/30
# 89/89 - 95s - loss: 2.7405 - accuracy: 0.9833 - val_loss: 2.9587 - val_accuracy: 0.8872
# Epoch 30/30
# 89/89 - 97s - loss: 2.6146 - accuracy: 0.9870 - val_loss: 2.8621 - val_accuracy: 0.8825

# %%
tf.saved_model.save(model, os.path.join(logdir, "model"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               327936
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 23)                1495
# =================================================================
# Total params: 2,603,863
# Trainable params: 2,569,751
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
# plot training and validation history
hist = training_history.history
train_loss = hist["loss"]
test_loss = hist["val_loss"]
train_accuracy = hist["accuracy"]
test_accuracy = hist["val_accuracy"]

plt.figure(figsize=(12,12))
plt.subplot(2,1,1)
ax = plt.gca()
ax.set_xlim([0, len(train_loss) + 1])
plt.ylabel('Loss')
plt.plot(range(1, len(train_loss)+1), train_loss, 'r', label='Training Loss')
plt.plot(range(1, len(test_loss)+1), test_loss, 'b', label='Test Loss')
ax.grid(linestyle='-.')
plt.legend()
plt.subplot(2,1,2)
ax = plt.gca()
ax.set_xlim([0, len(train_accuracy) + 1])
plt.ylabel('Accuracy')
plt.plot(range(1, len(train_accuracy)+1), train_accuracy, 'r', label='Training Accuracy')
plt.plot(range(1, len(test_accuracy)+1), test_accuracy, 'b', label='Test Accuracy')
ax.grid(linestyle='-.')
plt.legend()
plt.savefig(os.path.join(logdir, 'training_hist.png'))

# %%
def img_preprocessing(path):
    img = load_and_preprocess_image(path)
    img, _ = change_range(img,label=0)
    return img

test_df = pd.read_csv("test_df.csv")
test_image_paths = test_df.loc[:, "Image_File"].tolist()
test_image_labels = test_df.loc[:, "Label"].tolist()

rand_indx = random.randint(0, len(test_image_paths)-1)
img = img_preprocessing(test_image_paths[rand_indx]) 
plt.imshow(img)
# Out:
# W0417 23:29:27.787710 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
num_images=100
classes = ["AJ "+str(i) for i in range(1,24)]
indices = np.random.choice(len(test_image_paths), num_images, replace=False)
inputs = np.empty(shape=(num_images,224,224,3))
targets = np.empty(shape=(num_images))
for i, indx in enumerate(indices):
    inputs[i,:,:,:] = img_preprocessing(test_image_paths[indx]).numpy()
    targets[i] = test_image_labels[indx]
output = model.predict(inputs)
prediction = output.argmax(axis=1)
targets = targets.astype(int)
# output.shape
# output.argmax(axis=1)==targets

images_so_far = 0
fig = plt.figure(figsize=(16,40))

for i in range(num_images):
    images_so_far += 1
    ax = plt.subplot(num_images//5, 5, images_so_far)
    ax.axis('off')
    ax.set_title('Actual:{}, Predicted:{}'.format(classes[targets[i]], classes[prediction[i]]),
    color = 'k' if targets[i]==prediction[i] else 'r' )
    plt.imshow(inputs[i,:,:,:])
# Out:
# W0418 00:11:32.975531 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:32.992308 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.007484 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.024728 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.049598 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.065631 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.081521 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.097491 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.113471 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.129447 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.145347 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.162528 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.178649 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.194737 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.210360 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.225755 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.242795 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.263995 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.279192 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.294218 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.309942 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.327737 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.343099 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.361478 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.377806 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.393848 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.410475 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.427114 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.443223 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.462901 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.478857 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.496044 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.516112 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.532387 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.552374 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.569327 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.586591 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.609715 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.626192 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.642090 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.659466 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.677422 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.697441 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.713578 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.732065 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.749842 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.766108 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.782842 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.803692 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.821106 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.838361 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.857435 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.874186 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.893363 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.910206 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.926548 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.942654 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.963735 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:33.982413 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.000756 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.017166 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.033296 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.051444 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.067775 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.085134 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.103530 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.120112 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.136564 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.155901 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.172643 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.189993 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.208214 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.224717 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.241139 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.259453 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.276582 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.295642 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.314329 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.331403 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.350622 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.368988 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.385830 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.403378 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.421534 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.439630 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.458766 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.475764 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.496752 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.513890 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.531369 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.550268 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.567741 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.584882 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.602660 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.619977 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.637297 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.654627 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.672932 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.690152 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0418 00:11:34.707300 140663274698496 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
